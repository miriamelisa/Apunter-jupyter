# %%
import requests
from bs4 import BeautifulSoup

# %%
#ESTO ES UN RASPADO
url="https://es.wikipedia.org/wiki/Mecanismo_de_Anticitera"
contenido=requests.get(url)
soup=BeautifulSoup(contenido.text,"html.parser")
#"haces la sopa" conbiertelo a texto plano tipo html()
#soup-sopa=conte nido de una pagina web 
#quiero sacar las etiquetas h1
etih1=soup.find_all("h1") #de toda la sopa quiero encontrar H1
#BUCLE: LLEE LOS TITULOS Y LOS METE EN UNA VARIABLE LLAMDA TITULOS
titulos=[h1.get_text() for h1 in etih1]
#para VER LOS titulos
for titulo in titulos:
    print("Titulos: ",titulo)
# Out:
# Titulos:  Mecanismo de Anticitera

# %%
#ESTO ES UN RASPADO
url="https://es.wikipedia.org/wiki/Mecanismo_de_Anticitera"
contenido=requests.get(url)
soup=BeautifulSoup(contenido.text,"html.parser")
#"haces la sopa" conbiertelo a texto plano tipo html()
#soup-sopa=conte nido de una pagina web 
#quiero sacar las etiquetas p
ps=soup.find_all("p") #de toda la sopa quiero encontrar P
#BUCLE: LLEE LOS PARRAFOS Y LOS METE EN UNA VARIABLE LLAMDA PARRAFOS
parrafos=[p.get_text() for p in ps]
#para VER LOS titulos
for parrafo in parrafos:
    print("Parrafos: ",parrafo)
# Out:
# Parrafos:  El mecanismo de Anticitera es una computadora analógica[1]​[2]​[3]​[4]​ (o mecánica) de la antigüedad. Supuestamente construido por científicos griegos, el instrumento se data entre los años 150 a. C. y 100 a. C.,[5]​ o, según una observación reciente, hacia el año 200 a. C.[6]​[7]​ El componente fue recuperado en el mar Egeo, entre los años 1900 y 1901, de un antiguo naufragio cercano a la isla griega de Anticitera.[8]​ Este artefacto aparentemente fue diseñado para predecir posiciones astronómicas y los eclipses de hasta diecinueve años con propósitos astrológicos y calendáricos,[5]​[9]​[10]​ y predecir también la fecha exacta de seis certámenes griegos antiguos, entre los que se encuentran los cuatro principales juegos Panhelénicos y dos juegos más de menor entidad.[11]​[12]​
#
# ...

# %%
#ESTO ES UN RASPADO
url="https://es.wikipedia.org/wiki/Mecanismo_de_Anticitera"
contenido=requests.get(url)
soup=BeautifulSoup(contenido.text,"html.parser")
#"haces la sopa" conbiertelo a texto plano tipo html()
#soup-sopa=conte nido de una pagina web 
#quiero sacar las etiquetas a
aas=soup.find_all("a") #de toda la sopa quiero encontrar a
#BUCLE: LLEE LOS LINKS Y LOS METE EN UNA VARIABLE LLAMDA LINKS
links=[a.get_text() for a in aas]
#para VER LOS titulos
for link in links:
    print("Links: ",link)
# Out:
# Links:  Ir al contenido
# Links:  Portada
# Links:  Portal de la comunidad
# Links:  Actualidad
# Links:  Cambios recientes
# Links:  Páginas nuevas
# Links:  Página aleatoria
# Links:  Ayuda
# Links:  Donaciones
# Links:  Notificar un error
# Links:
#
#
#
#
#
#
# Links:
# Buscar
#
# Links:  Crear una cuenta
# Links:  Acceder
# Links:   Crear una cuenta
# Links:   Acceder
# Links:  más información
# Links:  Contribuciones
# Links:  Discusión
# Links:
# Inicio
#
# Links:
#
# 1Historia
#
# Links:
#
# 1.1Descubrimiento
#
# Links:
#
# 1.2Investigaciones sobre su cronología y origen
#
# Links:
#
# 2Descripción
#
# Links:
#
# 2.1Fragmentos mayores
#
# Links:
#
# 2.2Fragmentos menores
#
# Links:
#
# 3Mecanismo
#
# Links:
#
# 3.1Operación
#
# Links:
#
# 3.2Caras
#
# Links:
#
# 3.2.1Cara anterior
#
# Links:
#
# 3.2.2Cara posterior
#
# Links:
#
# 3.3Puertas
#
# Links:
#
# 3.4Engranaje
#
# Links:
#
# 3.4.1Esquema de los engranes conocidos
#
# Links:
#
# 3.4.2Esquemas de engranajes propuestos
#
# ...

# %%
bs=soup.find_all("b") #de toda la sopa quiero encontrar a
#BUCLE: LLEE LOS LINKS Y LOS METE EN UNA VARIABLE LLAMDA LINKS
palabrasennegrita=[b.get_text() for b in bs]
#para VER LOS titulos
for p in palabrasennegrita:
    print("Palabras en Negrita: ",palabrasennegrita)
# Out:
# Palabras en Negrita:  ['mecanismo de Anticitera', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'a', 'b', 'c', 'd', 'e', 'a', 'b', 'c', 'd', 'e', 'f', 'engrane solar', 'conjunto de engranes luna', 'conjunto de engranes metónico', 'conjunto de engranes olímpico', 'conjunto de engranes calípico', 'conjunto de engranes de Saros', 'conjunto de engranes de exeligmos', 'Michael Wright', 'Evans, Carman y Thorndike', 'Freeth y Jones', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'ñ', 'o', 'p', 'q', 'a', 'b', 'c', '68', 'a', 'b', 'a', 'b', '64', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'ñ', 'o', 'p', 'q', 'r', 's', 't', '26', 'a', 'b', 'c', 'd', '454', 'a', 'b', 'c', 'd', '444', 'a', 'b', 'c', 'd', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm', 'n', 'ñ', '32', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', '444', 'a', 'b', 'a', 'b', '301', '29', 'a', 'b', 'c', '85', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', '43', 'a', 'b', '314', '
# ...

# %%
etih1=soup.find_all("h1") #de toda la sopa quiero encontrar H1
#BUCLE: LLEE LOS TITULOS Y LOS METE EN UNA VARIABLE LLAMDA TITULOS
titulos=[h1.get_text() for h1 in etih1]
print(etih1)#IMPRIME TODO LO QUE HAY EN EL H1 CON LA ETIQUETA

#para VER LOS titulos
for titulo in titulos:
    print("Titulos: ",titulo)
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Mecanismo de Anticitera</span></h1>]
# Titulos:  Mecanismo de Anticitera

# %%
etih1=soup.find_all("h1") #de toda la sopa quiero encontrar H1
#BUCLE: LLEE LOS TITULOS Y LOS METE EN UNA VARIABLE LLAMDA TITULOS
titulos=[h1.get_text() for h1 in etih1]
print(etih1)#IMPRIME TODO LO QUE HAY EN EL H1 CON LA ETIQUETA
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Mecanismo de Anticitera</span></h1>]
