# %%
import pandas as pd

# %%
dataframe=pd.read_csv('titanic.csv')
#Con pandas podemos leer un archivo CSV como el anterior y guardarlo en una variable dataframe para poder utilizarla
dataframe.head()
#cabeza del archivo
# Out:
#    1  0  3                            Braund, Mr. Owen Harris    male    22  \
# 0  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 2  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3  5  0  3                           Allen, Mr. William Henry    male  35.0
# 4  6  0  3                                   Moran, Mr. James    male   NaN
#
#    1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# 0    1    0          PC 17599  71.2833         C85  C
# 1    0    0  STON/O2. 3101282   7.9250         NaN  S
# 2    1    0            113803  53.1000        C123  S
# 3    0    0            373450   8.0500         NaN  S
# 4    0    0            330877   8.4583         NaN  Q

# %%
dataframe.describe()#me cuenta los datos totales que hay por cada celda es necesario añadir descripciones para asociar datos
# Out:
#                 1           0           3          22         1.1         0.1  \
# count  890.000000  890.000000  890.000000  713.000000  890.000000  890.000000
# mean   446.500000    0.384270    2.307865   29.709916    0.522472    0.382022
# std    257.065167    0.486696    0.836220   14.533827    1.103247    0.806409
# min      2.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    224.250000    0.000000    2.000000   20.000000    0.000000    0.000000
# 50%    446.500000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    668.750000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              7.25
# count  890.000000
# mean    32.232246
# std     49.714317
# min      0.000000
# 25%      7.925000
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
dataframe=pd.read_csv('titanic.csv',header=None, names=['id_pasajero','Supervivientes','Clase','Sexo','Edad','SibSp','Parch','Cabina','Embarque'])
#con el comando anterior utilizamos en la cabecera donde no hay nada los nombres que queremos asociar respectivamente
#BASICAMENTE COLOCAR LOS LOS NOMBRES EN LA CABECERA 

dataframe.head()
# Out:
#                                              id_pasajero Supervivientes  \
# 1 0 3                            Braund, Mr. Owen Harris           male
# 2 1 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         female
# 3 1 3                             Heikkinen, Miss. Laina         female
# 4 1 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female
# 5 0 3                           Allen, Mr. William Henry           male
#
#        Clase  Sexo  Edad             SibSp    Parch Cabina Embarque
# 1 0 3   22.0     1     0         A/5 21171   7.2500    NaN        S
# 2 1 1   38.0     1     0          PC 17599  71.2833    C85        C
# 3 1 3   26.0     0     0  STON/O2. 3101282   7.9250    NaN        S
# 4 1 1   35.0     1     0            113803  53.1000   C123        S
# 5 0 3   35.0     0     0            373450   8.0500    NaN        S

# %%
dataframe.to_csv('titanic_puntocoma.csv', sep=";")
#es te comando me rea un nuevo documento Excel con los datos separados por punto y coma, podemos colocar cualqueir separador para ahcerlo
#
dt=pd.read_csv('titanic_puntocoma.csv')
dt.head()
# Out:
#                 ;;;id_pasajero;Supervivientes;Clase;Sexo;Edad;SibSp;Parch;Cabina;Embarque
# 1;0;3;Braund       Mr. Owen Harris;male;22.0;1;0;A/5 21171;7.25;;S
# 2;1;1;Cumings     Mrs. John Bradley (Florence Briggs Thayer);fe...
# 3;1;3;Heikkinen   Miss. Laina;female;26.0;0;0;STON/O2. 3101282;...
# 4;1;1;Futrelle    Mrs. Jacques Heath (Lily May Peel);female;35....
# 5;0;3;Allen         Mr. William Henry;male;35.0;0;0;373450;8.05;;S

# %%
dataframe.to_csv('titanic_puntocoma.csv', sep="\t")
#cumple la misma funcion que la anterior pero utilizamos un separador diferente
dt=pd.read_csv('titanic_puntocoma.csv')
dt.head()
# Out:
#                    \t\t\tid_pasajero\tSupervivientes\tClase\tSexo\tEdad\tSibSp\tParch\tCabina\tEmbarque
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22.0\t1\t0\tA/5 21171\...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26.0\t0\t0\tSTON/O2. 310...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35.0\t0\t0\t373450\t...

# %%
pd.read_csv('titanic.csv').head()
# Out:
#    1  0  3                            Braund, Mr. Owen Harris    male    22  \
# 0  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 2  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3  5  0  3                           Allen, Mr. William Henry    male  35.0
# 4  6  0  3                                   Moran, Mr. James    male   NaN
#
#    1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# 0    1    0          PC 17599  71.2833         C85  C
# 1    0    0  STON/O2. 3101282   7.9250         NaN  S
# 2    1    0            113803  53.1000        C123  S
# 3    0    0            373450   8.0500         NaN  S
# 4    0    0            330877   8.4583         NaN  Q

# %%
dataf=pd.read_excel('medicos.xlsx')
#CON ESTA FUNCION PUEDO ABRIR UN ARCHIVO XLSX EXCEL para guardarlo en una variable y jugar con los datos
dataf.head()
# Out:
#    Nº Registro Referencia CCAA  \
# 0  RXM-VAT-001        VRX-1/92
# 1  RXM-VAT-002        VRX-2/92
# 2  RXM-VAT-003        VRX-3/92
# 3          NaN       ERX-TF/03
# 4  RXM-VAT-004        VRX-4/93
#
#                                            Empresa  \
# 0                    COMERCIAL CENTRO MEDICO, S.L.
# 1                                    IBERMAN, S.A.
# 2                                    TEDIA'X, S.A.
# 3                                              NaN
# 4  INGENIERÍA TÉCNICA HOSPITALARIA (INTEFCH), S.L.
#
#                             Dirección       CP Población Provincia  \
# 0     Plaza Poeta Miguel Hernández, 5  50007.0  Zaragoza  Zaragoza
# 1  Avda. Diagonal Plaza nº 14 nave 61  50197.0  Zaragoza  Zaragoza
# 2      C/ Alcalá de la Selva, 1 bajos  50010.0  Zaragoza  Zaragoza
# 3                                 NaN      NaN       NaN       NaN
# 4                 C/ Atair, 29, Bajos  50012.0  Zaragoza  Zaragoza
#
# ...

# %%
dt=pd.read_fwf('personas.txt')
#con esta funcion puedo leer un archivo TXT
dt.head()
# Out:
#    Nombre;telefono,edad
# 0   Miriam,603385235,26
# 1   Fenando,62540315,28
# 2  Liliana,213546543,45
# 3   Miguel,602154521,54

# %%
dtj=pd.read_json('Film.JSON')
#con este comando puedo leer un archivo JSOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOON! XD
dtj.head()
# Out:
#                      Title  Year  Rated     Released  Runtime  \
# 0                   Avatar  2009  PG-13  18 Dec 2009  162 min
# 1              I Am Legend  2007  PG-13  14 Dec 2007  101 min
# 2                      300  2006      R  09 Mar 2007  117 min
# 3             The Avengers  2012  PG-13  04 May 2012  143 min
# 4  The Wolf of Wall Street  2013      R  25 Dec 2013  180 min
#
#                         Genre          Director  \
# 0  Action, Adventure, Fantasy     James Cameron
# 1       Drama, Horror, Sci-Fi  Francis Lawrence
# 2      Action, Drama, Fantasy       Zack Snyder
# 3    Action, Sci-Fi, Thriller       Joss Whedon
# 4    Biography, Comedy, Crime   Martin Scorsese
#
#                                               Writer  \
# 0                                      James Cameron
# 1  Mark Protosevich (screenplay), Akiva Goldsman ...
# 2  Zack Snyder (screenplay), Kurt Johnstad (scree...
# 3  Joss Whedon (screenplay), Zak Penn (story), Jo...
# ...

# %%
import zipfile
#para extraer el contenido de archivos ZIP
zf= zipfile.ZipFile('titanic.zip')
#guardamos en una variable 
dfl=pd.read_csv(zf.open('titanic.csv'))
dfl.head()
# Out:
#    1  0  3                            Braund, Mr. Owen Harris    male    22  \
# 0  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 2  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3  5  0  3                           Allen, Mr. William Henry    male  35.0
# 4  6  0  3                                   Moran, Mr. James    male   NaN
#
#    1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# 0    1    0          PC 17599  71.2833         C85  C
# 1    0    0  STON/O2. 3101282   7.9250         NaN  S
# 2    1    0            113803  53.1000        C123  S
# 3    0    0            373450   8.0500         NaN  S
# 4    0    0            330877   8.4583         NaN  Q
